# %% [markdown]
# <a href="https://colab.research.google.com/github/cindylrs04/PCVK25_3F_06/blob/main/Week1_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Langkah 2

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/143988513?v=4"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# Langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  230  x  230
# <PIL.Image.Image image mode=RGB size=230x230>

# %% [markdown]
# Langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# Pertanyaan Praktikum D2
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# jawab : Praktikum ini menggunakan Google Colab karena lebih praktis dan mudah diakses. Dengan Colab kita bisa langsung menulis dan menjalankan kode Python di browser tanpa harus instalasi Python maupun library di laptop.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# jawab: Pada langkah kedelapan ada beberapa library yang dipakai dengan fungsi yang berbeda. NumPy dipakai untuk mengolah data berbentuk array, karena gambar digital itu sebenarnya kumpulan pixel yang disusun seperti matriks. Pandas biasanya dibuat mengolah data tabel, tapi di praktikum ini jarang dipakai. OpenCV (cv2) jadi library utama buat membaca gambar, menampilkan, ubah ukuran, sampai edit gambar. Skimage juga bisa dipakai jika butuh pemrosesan citra yang lebih lanjut, sedangkan PIL berguna buat membuka dan mengatur gambar dari berbagai format file. Terakhir, Matplotlib dipakai untuk menampilkan gambar atau hasil pengolahan langsung di notebook.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
# jawab: Potongan kode image = cv.resize(image, (0,0), fx=0.5, fy=0.5) digunakan untuk mengecilkan ukuran gambar menjadi setengah dari ukuran aslinya, baik pada lebar maupun tinggi. Jika kode ini tidak dijalankan, gambar akan tetap berukuran besar. Hal tersebut dapat membuat tampilan gambar kurang nyaman, memakan memori lebih banyak, dan memperlambat proses komputasi.
#
# 4. Perhatikan potongan kode progam berikut :
# membuat garis horizontal ditengah image
# for y in range (lebar):
# image_3[int((tinggi)/2),y] = [255,255,255]
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# jawab: Pada kode image_3[int((tinggi)/2), y] = [255,255,255], bagian [255,255,255] menunjukkan warna putih dalam format RGB. Angka 255 di setiap kanal (Red, Green, dan Blue) berarti nilainya maksimum sehingga menghasilkan warna putih. Perintah ini membuat garis horizontal berwarna putih yang terletak tepat di tengah gambar.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# jawab: Pixel adalah bagian terkecil yang menyusun sebuah gambar digital, sedangkan resolusi adalah jumlah pixel yang ada pada lebar dan tinggi gambar. Keduanya saling berkaitan, karena semakin tinggi resolusi maka jumlah pixel semakin banyak sehingga gambar terlihat lebih detail dan jelas, meskipun ukuran filenya juga lebih besar. Sebaliknya, jika resolusi rendah maka jumlah pixel lebih sedikit sehingga gambar jadi kurang detail dan bisa terlihat pecah saat diperbesar, tetapi ukuran filenya lebih kecil.

# %% [markdown]
# #Tugas Praktikum D2

# %% [markdown]
# Membuat garis vertikal

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar, _ = image.shape

for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]

for i in range(min(tinggi, lebar)):
    image_3[i, lebar - 1 - i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# Buat garis horizontal berwarna putih dibagian tengah gambar dengan panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang = int(lebar / 2)

start_x = int((lebar - panjang) / 2)
end_x   = start_x + panjang

for x in range(start_x, end_x):
    image_3[int(tinggi/2), x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar, _ = image.shape

start_y, start_x = 50, 50
box_height, box_width = 80, 110

for y in range(start_y, start_y + box_height):
    for x in range(start_x, start_x + box_width):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>
